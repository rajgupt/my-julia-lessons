# %%
using Plots

# %%
globaltemperatures = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
numpirates = [45000, 20000, 15000, 5000, 400, 17];

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points")
xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")

# %%
scatter(numpirates, globaltemperatures, label="points")
plot!(numpirates, globaltemperatures, label="line")  
xflip!()

# %%
x = -10:10
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout = (2, 2), legend = false)

# %%
methods(plot)
# Out:
# # 3 methods for generic function "plot":
# [1] plot(plt1::Plots.Plot, plts_tail::Plots.Plot...; kw...) in Plots at /Users/rgupta98/.julia/packages/Plots/uCh2y/src/plot.jl:63
# [2] plot(sp::Plots.Subplot, args...; kw...) in Plots at /Users/rgupta98/.julia/packages/Plots/uCh2y/src/plot.jl:208
# [3] plot(args...; kw...) in Plots at /Users/rgupta98/.julia/packages/Plots/uCh2y/src/plot.jl:51
